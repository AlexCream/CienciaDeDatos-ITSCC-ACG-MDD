# %%
import pandas as pd
from scipy import stats
import numpy as np
path = "https://raw.githubusercontent.com/AlexCream/CienciaDeDatos-ITSCC-ACG-MDD/main/pipol_datos.csv"
data = pd.read_csv(path,index_col=[0])
data.columns = ["age", "sex", "income","height", "city", "education", "children"]
print(data.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 7 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   age        100000 non-null  int64
#  1   sex        90000 non-null   str
#  2   income     100000 non-null  int64
#  3   height     100000 non-null  float64
#  4   city       90000 non-null   str
#  5   education  77563 non-null   str
#  6   children   100000 non-null  int64
# dtypes: float64(1), int64(3), str(3)
# memory usage: 5.3 MB
# None

# %%
from Limpieza import FuncionDeLimpiezaEspecifica

data_clean = FuncionDeLimpiezaEspecifica(data, 4, 2)
# Out:
# ELIMINACION DE FILAS COMPLETAMENTE BASURA
# Filas originales:  100000
# Filas basura:      9943
# Filas conservadas: 90057
#
# TRATAMIENTO POR EDAD
# Filas originales:  90057
# Filas basura:      57
# Filas conservadas: 90057
#
# TRATAMIENTO POR SEXO
# Campos nulos de sexo: 57
# Valores únicos: sex
# M      45239
# F      44761
# NaN       57
# Name: count, dtype: int64

# %%
data_sex = data_clean["sex"]
print("Validacion del campo sex")
print("Nulos:",data_sex.isnull().sum())
print("Masculinos: ", data_sex[data_sex=="M"].shape[0])
print("Femeninos: ", data_sex[data_sex=="F"].shape[0])
#print("Otros: ", data_sex)
# Out:
# Validacion del campo sex
# Nulos: 57
# Masculinos:  45239
# Femeninos:  44761

# %%
print(data_clean[data_clean["sex"].isnull()])
# Out:
#        age  sex  income  height city     education  children
# 79     100  NaN  170167    1.63  NaN        mastre        -3
# 4138   100  NaN  197685    1.58  NaN  no education        -1
# 4761   100  NaN  152295    1.83  NaN  no education        -1
# 6989   100  NaN  196923    1.85  NaN  no education        -2
# 8301   100  NaN  157367    1.93  NaN     Bachelors        -5
# 11242  100  NaN  197093    1.65  NaN  no education        -2
# 11914  100  NaN  181068    1.59  NaN        mastre        -4
# 13736  100  NaN  167823    1.86  NaN  no education        -5
# 13837  100  NaN  179632    1.87  NaN     Bachelors        -5
# 18013  100  NaN  187746    1.68  NaN  no education        -3
# 20813  100  NaN  164691    1.54  NaN     Bachelors        -3
# 22803  100  NaN  165025    1.78  NaN        mastre        -3
# 24995  100  NaN  163382    1.65  NaN     Bachelors        -3
# 25466  100  NaN  162369    1.50  NaN     Bachelors        -3
# ...
