# %%
import pandas as pd
from scipy import stats
import numpy as np

path = "https://raw.githubusercontent.com/AlexCream/CienciaDeDatos-ITSCC-ACG-MDD/main/pipol_datos.csv"
data = pd.read_csv(path,index_col=[0])
data.columns = ["age", "sex", "income","height", "city", "education", "children"]
print(data.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 7 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   age        100000 non-null  int64
#  1   sex        90000 non-null   str
#  2   income     100000 non-null  int64
#  3   height     100000 non-null  float64
#  4   city       90000 non-null   str
#  5   education  77563 non-null   str
#  6   children   100000 non-null  int64
# dtypes: float64(1), int64(3), str(3)
# memory usage: 5.3 MB
# None

# %%
def identificar_filas_basura(df, umbral_campos_invalidos=3):
    condiciones = pd.DataFrame()
    condiciones["age_invalida"]      = (df["age"] > 150) | (df["age"] < 0)
    condiciones["sex_nulo"]          = df["sex"].isnull()
    condiciones["income_negativo"]   = df["income"] < 0
    condiciones["children_negativo"] = df["children"] < 0
    condiciones["city_nula"]         = df["city"].isnull()

    df["campos_invalidos"] = condiciones.sum(axis=1)

    filas_basura = df[df["campos_invalidos"] >= umbral_campos_invalidos]
    filas_limpias = df[df["campos_invalidos"] < umbral_campos_invalidos].drop(columns="campos_invalidos")

    return filas_limpias, filas_basura
    
data_limpia, data_basura = identificar_filas_basura(data,4)

print(f"Filas originales:  {data.shape[0]}")
print(f"Filas basura:      {data_basura.shape[0]}")
print(f"Filas conservadas: {data_limpia.shape[0]}")
# Out:
# Filas originales:  100000
# Filas basura:      9943
# Filas conservadas: 90057
